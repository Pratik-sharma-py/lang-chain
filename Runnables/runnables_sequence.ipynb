# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv
from langchain_cohere import ChatCohere
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableSequence

# %%
load_dotenv()
# Out:
# True

# %%
prompt1 = PromptTemplate(
    template="Write a joke on {topic}",
    input_variables=['topic']
)

# %%
model = ChatCohere(model="command-r-plus-08-2024")
parser = StrOutputParser()

# %%
prompt2 = PromptTemplate(
    template="Explain the joke {text}",
    input_variables=['text']
)

# %%
chain = RunnableSequence( prompt1, model, parser, prompt2, model, parser )

# %%
print(chain.invoke({'topic':'AI'}))
# Out:
# This joke plays on a pun, combining two common phrases: "I have an idea" and "I have a wild guess."
#
# When someone says they have an "elephant idea," it's a humorous way of expressing that their idea or guess is a very large or significant one, just like an elephant. In the context of the joke, the computer is suggesting that it has a big or grand idea about what the animal might be, but it's also a play on words, as "elephant idea" sounds similar to "I have an idea."
#
# The joke relies on the double meaning and the unexpected use of the word "elephant" to create humor. It's a lighthearted play on language and the idea of a computer attempting to guess an animal.
